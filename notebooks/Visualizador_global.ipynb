# %%
import json
import ipywidgets as widgets
from src.helpers import read_and_concatenate_excel
from src.graphics import bar_plot_by_category_from_multy_sheets, create_multy_bar_diagram

# %%
file_categorias = "categorias.json"
comercio_categoria_dict = json.load(open(file_categorias))
categories = list(set(list(comercio_categoria_dict.values())))
df = read_and_concatenate_excel('mis_gastos.xlsx')

# %%
df
# Out:
#          FECHA            COMERCIO/CAJERO MOVIMIENTO A  IMPORTE  \
# 0   2024-04-30                HD PORTUGAL      Crédito    -2.79
# 1   2024-04-30       FRANELA ROSA MODISTA      Crédito    -3.00
# 2   2024-04-30             GRUPO BHP 2020      Crédito    -5.99
# 3   2024-04-30  MERCADONA REPUBLICA DOMIN      Crédito   -11.53
# 4   2024-04-30             SPAR LA ISLETA      Crédito   -12.90
# ..         ...                        ...          ...      ...
# 229 2024-06-11       ESQUINITA DE CEBRIAN      Crédito    -4.50
# 230 2024-06-12    HD BERNARDO DE LA TORRE      Crédito    -2.61
# 231 2024-06-12                 EL MOMENTO      Crédito    -3.40
# 232 2024-06-12               LOS MILAGROS      Crédito    -4.20
# 233 2024-06-12       GALERIA BELLAS ARTES      Crédito   -14.38
#
#     Tipo de Comercio
# 0       supermercado
# 1               ropa
# 2              otros
# 3       supermercado
# 4       supermercado
# ..               ...
# 229         desayuno
# ...

# %%
# Crear el widget Dropdown
selection = widgets.Dropdown(
    options=categories,
    description='Category:',
    disabled=False,
)

# Definir la función que se ejecutará cuando cambie el valor del widget
# TODO no funciona
# def on_category_change(change, df):
#     if change['type'] == 'change' and change['name'] == 'value':
#         # Limpiar la salida para evitar que los gráficos se acumulen
#         display.clear_output(wait=True)
#         display(selection)
#         bar_plot_by_category_from_multy_sheets(df, change['new'])
# 
# # Vincular la función al evento de cambio del widget usando una función lambda
# selection.observe(lambda change: on_category_change(change, df), names='value')
display(selection)
# Out:
# Dropdown(description='Category:', options=('bar', 'vacaciones', 'servicios de internet', 'desayuno', 'ropa', '…

# %%
bar_plot_by_category_from_multy_sheets(df, selection.value)

# %%
create_multy_bar_diagram(df, stack = True)
