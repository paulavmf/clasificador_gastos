# %%
import json

import pandas as pd
import ipywidgets as widgets

from graphics import crear_grafico_quesos, crear_linea_temporal
from src.helpers import get_categories_from_df, filter_df_by_category
  
path_to_mis_gastos = 'mis_gastos.xlsx' 
df = pd.read_excel(path_to_mis_gastos, sheet_name='2024-03')

# %%
crear_grafico_quesos(df)

# %%
crear_linea_temporal(df)

# %%
selection = widgets.Dropdown(
    options=get_categories_from_df(df),
    description='Category:',
    disabled=False,
)
display(selection)
# Out:
# Dropdown(description='Category:', options=('bar', 'restaurante', 'otros', 'servicios de internet'), value='bar…

# %%
df_category = filter_df_by_category(df, selection.value)
crear_linea_temporal(df_category, selection.value)
# Out:
# /home/paula/Documentos/clasificador_gastos/graphics.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Fecha'] = pd.to_datetime(df['FECHA']).copy()
